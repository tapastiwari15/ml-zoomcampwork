# %%
import pandas as pd
import numpy as np
import os

# %%
np.__version__
# Out:
# '1.20.1'

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
df=pd.read_csv('C:\\Users\\Tapas.Tiwari\\Desktop\\Python Notebooks\\ml-zoomcamp\\carpricedata.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
bmw = df[df['Make']== "BMW"]
avgprice = bmw['MSRP'].mean()
avgprice
# Out:
# 61546.76347305389

# %%
after2015 = df[df['Year']>=2015]
after2015.head()
# Out:
#     Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41   BMW    2 Series  2016     premium unleaded (required)      240.0
# 42   BMW    2 Series  2016     premium unleaded (required)      240.0
#
#     Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 32               4.0            MANUAL  rear wheel drive              2.0
# 33               4.0            MANUAL  rear wheel drive              2.0
# 34               4.0            MANUAL  rear wheel drive              2.0
# 41               4.0         AUTOMATIC  rear wheel drive              2.0
# 42               4.0         AUTOMATIC  rear wheel drive              2.0
#
#        Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %%
after2015.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
after2015['Engine HP'].mean()
# Out:
# 272.98771870794076

# %%
values = {'Engine HP': 272.98}
after2015.fillna(value = values)
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
after2015['Engine HP'].mean()
# Out:
# 272.98771870794076

# %%
rollsroyce = df[df['Make']== "Rolls-Royce"]
rollsroyce.head()
# Out:
#              Make            Model  Year             Engine Fuel Type  \
# 2921  Rolls-Royce         Corniche  2001  premium unleaded (required)
# 3505  Rolls-Royce             Dawn  2016  premium unleaded (required)
# 5275  Rolls-Royce  Ghost Series II  2015  premium unleaded (required)
# 5276  Rolls-Royce  Ghost Series II  2015  premium unleaded (required)
# 5277  Rolls-Royce  Ghost Series II  2016  premium unleaded (required)
#
#       Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 2921      325.0               8.0         AUTOMATIC  rear wheel drive
# 3505      563.0              12.0         AUTOMATIC  rear wheel drive
# 5275      563.0              12.0         AUTOMATIC  rear wheel drive
# 5276      563.0              12.0         AUTOMATIC  rear wheel drive
# 5277      563.0              12.0         AUTOMATIC  rear wheel drive
#
#       Number of Doors                 Market Category Vehicle Size  \
# ...

# %%
rollsroyce = rollsroyce[['Engine HP', 'Engine Cylinders', 'highway MPG']]

# %%
rollsroyce.head()
# Out:
#       Engine HP  Engine Cylinders  highway MPG
# 2921      325.0               8.0           15
# 3505      563.0              12.0           19
# 5275      563.0              12.0           21
# 5276      563.0              12.0           21
# 5277      563.0              12.0           21

# %%
rollsroyce.drop_duplicates()
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X = rollsroyce.values

# %%
X = np.array(X)

# %%
XT = X.T
XT
# Out:
# array([[325., 563., 563., 563., 563., 563., 563., 563., 563., 563., 563.,
#         563., 322., 322., 453., 453., 453., 453., 453., 453., 453., 453.,
#         453., 453., 453., 453., 322., 322., 624., 624., 624.],
#        [  8.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,
#          12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,
#          12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.,  12.],
#        [ 15.,  19.,  21.,  21.,  21.,  21.,  20.,  20.,  21.,  21.,  21.,
#          21.,  15.,  15.,  19.,  19.,  19.,  19.,  19.,  19.,  19.,  19.,
#          19.,  19.,  19.,  19.,  15.,  15.,  21.,  21.,  21.]])

# %%
XTX = XT.dot(X)
XTX
# Out:
# array([[7.637656e+06, 1.800680e+05, 2.945920e+05],
#        [1.800680e+05, 4.384000e+03, 7.056000e+03],
#        [2.945920e+05, 7.056000e+03, 1.146900e+04]])

# %%
XTXInv = np.linalg.inv(XTX)
XTXInv
# Out:
# array([[ 2.57536457e-05,  7.02210013e-04, -1.09352270e-03],
#        [ 7.02210013e-04,  4.24123405e-02, -4.41299962e-02],
#        [-1.09352270e-03, -4.41299962e-02,  5.53251629e-02]])

# %%
XTXInv.sum()
# Out:
# 0.008720639166869035

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
y
# Out:
# array([1000, 1100,  900, 1200, 1000,  850, 1300])

# %%
w1 = XTXInv.dot(XT)

# %%
w = y.dot(w1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-ce90a9efea54> in <module>
# ----> 1 w = y.dot(w1)
#
# ValueError: shapes (7,) and (3,31) not aligned: 7 (dim 0) != 3 (dim 0)
